# %%
# Import dependencies
import pandas as pd
import datetime as dt
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Load and read data
file = r"C:\Users\lenovo\Desktop/airline_satisfaction.csv"
df=pd.read_csv(file,parse_dates=True)
df.head()
# Out:
#     ID  Gender  Age      Customer Type   Type of Travel     Class  \
# 0  1.0    Male   13     Loyal Customer  Personal Travel  Eco Plus
# 1  2.0    Male   25  disloyal Customer  Business travel  Business
# 2  3.0  Female   26     Loyal Customer  Business travel  Business
# 3  4.0  Female   25     Loyal Customer  Business travel  Business
# 4  5.0    Male   61     Loyal Customer  Business travel  Business
#
#    Flight Distance  Departure Delay  Arrival Delay  \
# 0              460               25           18.0
# 1              235                1            6.0
# 2             1142                0            0.0
# 3              562               11            9.0
# 4              214                0            0.0
#
#    Departure Arrival Time Convenience  ...  Online Boarding  Seat Comfort  \
# 0                                   4  ...                3             5
# 1                                   2  ...                3             1
# 2                                   2  ...                5             5
# 3                                   5  ...                2             2
# 4                                   3  ...                5             5
#
#    Inflight Entertainment  Onboard Service  Leg Room Service  \
# 0                       5                4                 3
# 1                       1                1                 5
# 2                       5                4                 3
# 3                       2                2                 5
# 4                       3                3                 4
#
#    Baggage Handling  Check-in Service  In-flight Service  Cleanliness  \
# 0                 4                 4                  5            5
# 1                 3                 1                  4            1
# 2                 4                 4                  4            5
# 3                 3                 1                  4            2
# 4                 4                 3                  3            3
#
#               Satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 23 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
# See the shape of data
df.shape
# Out:
# (129880, 23)

# %%
# Check if there is any null values
df.isnull().sum()
# Out:
# ID                                      1
# Gender                                  0
# Age                                     0
# Customer Type                           0
# Type of Travel                          0
# Class                                   0
# Flight Distance                         0
# Departure Delay                         0
# Arrival Delay                         393
# Departure Arrival Time Convenience      0
# Ease of Online Booking                  0
# Gate Location                           0
# Food and Drink                          0
# Online Boarding                         0
# Seat Comfort                            0
# Inflight Entertainment                  0
# Onboard Service                         0
# Leg Room Service                        0
# Baggage Handling                        0
# Check-in Service                        0
# In-flight Service                       0
# Cleanliness                             0
# Satisfaction                            0
# dtype: int64

# %%
# Find the percentage of missing value
393/129880
# Out:
# 0.003025870033877425

# %% [markdown]
# Missing value comprise of 0.3% of the total data

# %%
# Use median method to fill missing values
df.fillna(df['Arrival Delay'].median(), inplace = True)

# %%
# Find the descriptive information of dataframe
df.describe().transpose()
# Out:
#                                        count          mean           std  \
# ID                                  129880.0  64939.500000  37493.270818
# Age                                 129880.0     39.427957     15.119360
# Flight Distance                     129880.0   1190.316392    997.452477
# Departure Delay                     129880.0     14.713713     38.071126
# Arrival Delay                       129880.0     15.045465     38.416353
# Departure Arrival Time Convenience  129880.0      3.057599      1.526741
# Ease of Online Booking              129880.0      2.756876      1.401740
# Gate Location                       129880.0      2.976925      1.278520
# Food and Drink                      129880.0      3.204774      1.329933
# Online Boarding                     129880.0      3.252633      1.350719
# Seat Comfort                        129880.0      3.441361      1.319289
# Inflight Entertainment              129880.0      3.358077      1.334049
# Onboard Service                     129880.0      3.383023      1.287099
# Leg Room Service                    129880.0      3.350878      1.316252
# Baggage Handling                    129880.0      3.632114      1.180025
# Check-in Service                    129880.0      3.306267      1.266185
# In-flight Service                   129880.0      3.642193      1.176669
# Cleanliness                         129880.0      3.286326      1.313682
#
#                                      min       25%      50%       75%  \
# ID                                   0.0  32469.75  64939.5  97409.25
# Age                                  7.0     27.00     40.0     51.00
# Flight Distance                     31.0    414.00    844.0   1744.00
# Departure Delay                      0.0      0.00      0.0     12.00
# Arrival Delay                        0.0      0.00      0.0     13.00
# Departure Arrival Time Convenience   0.0      2.00      3.0      4.00
# Ease of Online Booking               0.0      2.00      3.0      4.00
# Gate Location                        0.0      2.00      3.0      4.00
# Food and Drink                       0.0      2.00      3.0      4.00
# Online Boarding                      0.0      2.00      3.0      4.00
# Seat Comfort                         0.0      2.00      4.0      5.00
# Inflight Entertainment               0.0      2.00      4.0      4.00
# Onboard Service                      0.0      2.00      4.0      4.00
# Leg Room Service                     0.0      2.00      4.0      4.00
# Baggage Handling                     1.0      3.00      4.0      5.00
# Check-in Service                     0.0      3.00      3.0      4.00
# In-flight Service                    0.0      3.00      4.0      5.00
# Cleanliness                          0.0      2.00      3.0      4.00
#
#                                          max
# ID                                  129879.0
# Age                                     85.0
# Flight Distance                       4983.0
# Departure Delay                       1592.0
# Arrival Delay                         1584.0
# Departure Arrival Time Convenience       5.0
# Ease of Online Booking                   5.0
# Gate Location                            5.0
# Food and Drink                           5.0
# Online Boarding                          5.0
# Seat Comfort                             5.0
# Inflight Entertainment                   5.0
# Onboard Service                          5.0
# Leg Room Service                         5.0
# Baggage Handling                         5.0
# Check-in Service                         5.0
# In-flight Service                        5.0
# Cleanliness                              5.0

# %% [markdown]
# We can see that Flight Distance, Departure Delay and Arrival Delay have high variance

# %%
# Find the summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   ID                                  129880 non-null  float64
#  1   Gender                              129880 non-null  object
#  2   Age                                 129880 non-null  int64
#  3   Customer Type                       129880 non-null  object
#  4   Type of Travel                      129880 non-null  object
#  5   Class                               129880 non-null  object
#  6   Flight Distance                     129880 non-null  int64
#  7   Departure Delay                     129880 non-null  int64
#  8   Arrival Delay                       129880 non-null  float64
#  9   Departure Arrival Time Convenience  129880 non-null  int64
#  10  Ease of Online Booking              129880 non-null  int64
#  11  Gate Location                       129880 non-null  int64
#  12  Food and Drink                      129880 non-null  int64
#  13  Online Boarding                     129880 non-null  int64
#  14  Seat Comfort                        129880 non-null  int64
#  15  Inflight Entertainment              129880 non-null  int64
#  16  Onboard Service                     129880 non-null  int64
#  17  Leg Room Service                    129880 non-null  int64
#  18  Baggage Handling                    129880 non-null  int64
#  19  Check-in Service                    129880 non-null  int64
#  20  In-flight Service                   129880 non-null  int64
#  21  Cleanliness                         129880 non-null  int64
#  22  Satisfaction                        129880 non-null  object
# dtypes: float64(2), int64(16), object(5)
# memory usage: 22.8+ MB

# %%
# Inspect Outliers
plt.figure(figsize=(20,15))
check_list=['Flight Distance','Departure Delay','Arrival Delay']
for i in range(len(check_list)):
    plt.subplot(1, len(check_list), i+1) 
    plt.boxplot(df[check_list[i]]) 
    plt.title(check_list[i],fontsize=20)
    
plt.show()

# %% [markdown]
# We can see that Flight Distance, Departure Delay and Arrival Delay have some outliers

# %%
def copy_df(df):
    return df.copy()

# Remove the outliers 
def outliers(df, column):
    low = np.quantile(df[column], 0.05)
    high = np.quantile(df[column], 0.95)
    return df[df[column].between(low, high, inclusive = 'both')]

df = (df.pipe(copy_df).
          pipe(outliers, "Flight Distance").
          pipe(outliers, "Departure Delay").
          pipe(outliers, "Arrival Delay"))

# %%
df
# Out:
#               ID  Gender  Age      Customer Type   Type of Travel     Class  \
# 0            1.0    Male   13     Loyal Customer  Personal Travel  Eco Plus
# 1            2.0    Male   25  disloyal Customer  Business travel  Business
# 2            3.0  Female   26     Loyal Customer  Business travel  Business
# 3            4.0  Female   25     Loyal Customer  Business travel  Business
# 4            5.0    Male   61     Loyal Customer  Business travel  Business
# ...          ...     ...  ...                ...              ...       ...
# 129875  129876.0    Male   34  disloyal Customer  Business travel  Business
# 129876  129877.0    Male   23     Loyal Customer  Business travel  Business
# 129877  129878.0  Female   17     Loyal Customer  Personal Travel       Eco
# 129878  129879.0    Male   14     Loyal Customer  Business travel  Business
# 129879       0.0  Female   42     Loyal Customer  Personal Travel       Eco
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   460               25           18.0
# 1                   235                1            6.0
# 2                  1142                0            0.0
# 3                   562               11            9.0
# 4                   214                0            0.0
# ...                 ...              ...            ...
# 129875              526                0            0.0
# 129876              646                0            0.0
# 129877              828                0            0.0
# 129878             1127                0            0.0
# 129879              264                0            0.0
#
#         Departure Arrival Time Convenience  ...  Online Boarding  \
# 0                                        4  ...                3
# 1                                        2  ...                3
# 2                                        2  ...                5
# 3                                        5  ...                2
# 4                                        3  ...                5
# ...                                    ...  ...              ...
# 129875                                   3  ...                3
# 129876                                   4  ...                4
# 129877                                   5  ...                1
# 129878                                   3  ...                4
# 129879                                   5  ...                2
#
#         Seat Comfort  Inflight Entertainment  Onboard Service  \
# 0                  5                       5                4
# 1                  1                       1                1
# 2                  5                       5                4
# 3                  2                       2                2
# 4                  5                       3                3
# ...              ...                     ...              ...
# 129875             4                       4                3
# 129876             4                       4                4
# 129877             2                       2                4
# 129878             4                       4                3
# 129879             2                       1                1
#
#         Leg Room Service  Baggage Handling  Check-in Service  \
# 0                      3                 4                 4
# 1                      5                 3                 1
# 2                      3                 4                 4
# 3                      5                 3                 1
# 4                      4                 4                 3
# ...                  ...               ...               ...
# 129875                 2                 4                 4
# 129876                 5                 5                 5
# 129877                 3                 4                 5
# 129878                 2                 5                 4
# 129879                 2                 1                 1
#
#         In-flight Service  Cleanliness             Satisfaction
# 0                       5            5  neutral or dissatisfied
# 1                       4            1  neutral or dissatisfied
# 2                       4            5                satisfied
# 3                       4            2  neutral or dissatisfied
# 4                       3            3                satisfied
# ...                   ...          ...                      ...
# 129875                  5            4  neutral or dissatisfied
# 129876                  5            4                satisfied
# 129877                  4            2  neutral or dissatisfied
# 129878                  5            4                satisfied
# 129879                  1            1  neutral or dissatisfied
#
# [105722 rows x 23 columns]

# %%
plt.figure(figsize=(20,15))
for i in range(len(check_list)):
    plt.subplot(1, len(check_list), i+1) 
    plt.boxplot(df[check_list[i]]) 
    plt.title(check_list[i],fontsize=20)
    
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105722 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   ID                                  105722 non-null  float64
#  1   Gender                              105722 non-null  object
#  2   Age                                 105722 non-null  int64
#  3   Customer Type                       105722 non-null  object
#  4   Type of Travel                      105722 non-null  object
#  5   Class                               105722 non-null  object
#  6   Flight Distance                     105722 non-null  int64
#  7   Departure Delay                     105722 non-null  int64
#  8   Arrival Delay                       105722 non-null  float64
#  9   Departure Arrival Time Convenience  105722 non-null  int64
#  10  Ease of Online Booking              105722 non-null  int64
#  11  Gate Location                       105722 non-null  int64
#  12  Food and Drink                      105722 non-null  int64
#  13  Online Boarding                     105722 non-null  int64
#  14  Seat Comfort                        105722 non-null  int64
#  15  Inflight Entertainment              105722 non-null  int64
#  16  Onboard Service                     105722 non-null  int64
#  17  Leg Room Service                    105722 non-null  int64
#  18  Baggage Handling                    105722 non-null  int64
#  19  Check-in Service                    105722 non-null  int64
#  20  In-flight Service                   105722 non-null  int64
#  21  Cleanliness                         105722 non-null  int64
#  22  Satisfaction                        105722 non-null  object
# dtypes: float64(2), int64(16), object(5)
# memory usage: 19.4+ MB

# %%
df.to_csv('airlines_passenger_clean.csv')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Satisfaction

# %%
df.Satisfaction.value_counts()
# Out:
# Satisfaction
# neutral or dissatisfied    60529
# satisfied                  45193
# Name: count, dtype: int64

# %%
df.Satisfaction.value_counts(normalize=True)
# Out:
# Satisfaction
# neutral or dissatisfied    0.57253
# satisfied                  0.42747
# Name: proportion, dtype: float64

# %%
df.Satisfaction.value_counts().plot(kind="bar")
plt.title("Value counts of the target variable")
plt.xlabel("Satisfaction Level")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Type of Travel

# %%
df["Type of Travel"].value_counts().plot(kind="bar")
plt.xlabel("Type of Travel")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Customer Type

# %%
df["Customer Type"].value_counts().plot(kind="bar")
plt.xlabel("Type of Customer")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Age

# %%
plt.hist(df["Age"],color="green")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Flight Distance

# %%
plt.hist(df["Flight Distance"],color="green")
plt.xlabel("Flight Distance")
plt.ylabel("Frequency")
plt.show()

# %%
# Correlation among the variables
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, cmap="Oranges", fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Data Visualization and Analysis

# %% [markdown]
# Here, our analysis is based on satisfaction level and returning rate

# %%
# Look at Age value counts for binning
Age_counts = df.Age.value_counts()
Age_counts
# Out:
# Age
# 39    2937
# 25    2925
# 40    2576
# 44    2491
# 41    2475
#       ...
# 76      48
# 74      44
# 79      37
# 78      32
# 85      14
# Name: count, Length: 75, dtype: int64

# %%
# Create bins for age
bins = [0, 18, 30, 60, 100]
category = ['Minor','Young Adult','Adult','Elderly']
df['Age_category'] = pd.cut(df['Age'], bins, labels=category)

# %%
sns.catplot(y="Age_category", hue="Satisfaction", kind="count",
            palette="YlOrBr",
            data=df)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# We can see that minor, young adult and elderly people are neutral or dissatisfied with the flight service whereas adult are more satisfied

# %%
# Passenger returning rate based on Age
sns.catplot(y="Age_category", hue="Customer Type", kind="count",
            palette="YlOrBr",
            data=df)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Adult are more likely to return than passenger of other age groups

# %%
# Passenger satisfaction based on class
sns.catplot(y="Class", hue="Satisfaction", kind="count",
            palette="cubehelix",
            data=df)

# %% [markdown]
# We can see that business class passenger are more satisfied with the flight service whereas economy class passenger hare highly dissatisfied followed by Economy Plus class passenger

# %%
# Passenger returning rate based on Class
sns.catplot(y="Class", hue="Customer Type", kind="count",
            palette="cubehelix",
            data=df)

# %% [markdown]
# We can see that business class passenger have higher returing rate than other class

# %%
# Look at Flight distance counts for binning
Flight_counts = df["Flight Distance"].value_counts()
Flight_counts
# Out:
# Flight Distance
# 337     755
# 594     461
# 404     448
# 2475    434
# 862     429
#        ...
# 885       1
# 1421      1
# 877       1
# 1492      1
# 884       1
# Name: count, Length: 3099, dtype: int64

# %%
# Create bins for flght distance
bins = [0, 1000, 2500, 5000]
category = ['Short Haul','Medium Haul','Long Haul']
df['flight_distance'] = pd.cut(df['Flight Distance'], bins, labels=category)

# %%
sns.catplot(y="flight_distance", hue="Satisfaction", kind="count",
            palette="rocket",
            data=df)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# We can see that passenger in short haul flight are more dissatisfied with the flight service than medium haul and long haul flights.

# %%
# Passenger returning rate based on flight distance
df_distance = df[["flight_distance", "Customer Type"]]
df_distance=(df_distance.groupby("flight_distance")["Customer Type"].value_counts())/df['Customer Type'].value_counts()['Loyal Customer']
df_distance
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5664\52302005.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_distance=(df_distance.groupby("flight_distance")["Customer Type"].value_counts())/df['Customer Type'].value_counts()['Loyal Customer']
# flight_distance  Customer Type
# Short Haul       Loyal Customer       0.545340
#                  disloyal Customer    0.175678
# Medium Haul      Loyal Customer       0.341777
#                  disloyal Customer    0.055502
# Long Haul        Loyal Customer       0.112883
#                  disloyal Customer    0.002334
# Name: count, dtype: float64

# %%
sns.catplot(y="flight_distance", hue="Customer Type", kind="count",
            palette="rocket",
            data=df)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# We can see that short haul passenger have higher returning rate of 54.53% than in medium haul flights (34.17%) followed by long haul flights (11.28%)

# %%
## show the business class
df_business=df[df['Class']=='Business']
sns.set_style('whitegrid')
sns.set_context("paper", font_scale=1.3)
fig,ax = plt.subplots(1,1,figsize=(18,9))
sns.countplot(data=df_business,x='Age')
ax.set_title('Customer Count by Age in Business Class')
plt.tight_layout()
plt.show()

# %%
## show the Economy class
df_economy=df[df['Class']=='Eco']
sns.set_style('whitegrid')
sns.set_context("paper", font_scale=1.3)
fig,ax = plt.subplots(1,1,figsize=(18,9))
sns.countplot(data=df_economy,x='Age')
ax.set_title('Customer Count by Age in Economy Class')
plt.tight_layout()
plt.show()

# %%
## show the Economy plus class
df_economyplus=df[df['Class']=='Eco Plus']
sns.set_style('whitegrid')
sns.set_context("paper", font_scale=1.3)
fig,ax = plt.subplots(1,1,figsize=(18,9))
sns.countplot(data=df_economyplus,x='Age')
ax.set_title('Customer Count by Age in Economy Plus Class')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#               ID  Gender  Age      Customer Type   Type of Travel     Class  \
# 0            1.0    Male   13     Loyal Customer  Personal Travel  Eco Plus
# 1            2.0    Male   25  disloyal Customer  Business travel  Business
# 2            3.0  Female   26     Loyal Customer  Business travel  Business
# 3            4.0  Female   25     Loyal Customer  Business travel  Business
# 4            5.0    Male   61     Loyal Customer  Business travel  Business
# ...          ...     ...  ...                ...              ...       ...
# 129875  129876.0    Male   34  disloyal Customer  Business travel  Business
# 129876  129877.0    Male   23     Loyal Customer  Business travel  Business
# 129877  129878.0  Female   17     Loyal Customer  Personal Travel       Eco
# 129878  129879.0    Male   14     Loyal Customer  Business travel  Business
# 129879       0.0  Female   42     Loyal Customer  Personal Travel       Eco
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   460               25           18.0
# 1                   235                1            6.0
# 2                  1142                0            0.0
# 3                   562               11            9.0
# 4                   214                0            0.0
# ...                 ...              ...            ...
# 129875              526                0            0.0
# 129876              646                0            0.0
# 129877              828                0            0.0
# 129878             1127                0            0.0
# 129879              264                0            0.0
#
#         Departure Arrival Time Convenience  ...  Inflight Entertainment  \
# 0                                        4  ...                       5
# 1                                        2  ...                       1
# 2                                        2  ...                       5
# 3                                        5  ...                       2
# 4                                        3  ...                       3
# ...                                    ...  ...                     ...
# 129875                                   3  ...                       4
# 129876                                   4  ...                       4
# 129877                                   5  ...                       2
# 129878                                   3  ...                       4
# 129879                                   5  ...                       1
#
#         Onboard Service  Leg Room Service  Baggage Handling  Check-in Service  \
# 0                     4                 3                 4                 4
# 1                     1                 5                 3                 1
# 2                     4                 3                 4                 4
# 3                     2                 5                 3                 1
# 4                     3                 4                 4                 3
# ...                 ...               ...               ...               ...
# 129875                3                 2                 4                 4
# 129876                4                 5                 5                 5
# 129877                4                 3                 4                 5
# 129878                3                 2                 5                 4
# 129879                1                 2                 1                 1
#
#         In-flight Service  Cleanliness             Satisfaction  Age_category  \
# 0                       5            5  neutral or dissatisfied         Minor
# 1                       4            1  neutral or dissatisfied   Young Adult
# 2                       4            5                satisfied   Young Adult
# 3                       4            2  neutral or dissatisfied   Young Adult
# 4                       3            3                satisfied       Elderly
# ...                   ...          ...                      ...           ...
# 129875                  5            4  neutral or dissatisfied         Adult
# 129876                  5            4                satisfied   Young Adult
# 129877                  4            2  neutral or dissatisfied         Minor
# 129878                  5            4                satisfied         Minor
# 129879                  1            1  neutral or dissatisfied         Adult
#
#         flight_distance
# 0            Short Haul
# 1            Short Haul
# 2           Medium Haul
# 3            Short Haul
# 4            Short Haul
# ...                 ...
# 129875       Short Haul
# 129876       Short Haul
# 129877       Short Haul
# 129878      Medium Haul
# 129879       Short Haul
#
# [105722 rows x 25 columns]

# %%
# Import label encoder
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
# Convert all categorical variable into numerical variable
df['Age_category']= label_encoder.fit_transform(df['Age_category'])
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['flight_distance']= label_encoder.fit_transform(df['flight_distance'])
df['Customer Type']= label_encoder.fit_transform(df['Customer Type'])
df['Type of Travel']= label_encoder.fit_transform(df['Type of Travel'])
df['Class']= label_encoder.fit_transform(df['Class'])
df['Satisfaction']= label_encoder.fit_transform(df['Satisfaction'])

# %% [markdown]
# # Feature Selection based on RFE

# %%
# Create our features
X = df.drop(["Satisfaction","ID"],axis=1)

# Create our target
y = df.Satisfaction

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier

# %%
# Fit a Recursive Feature Elimination model
rfecv = RFECV(estimator=DecisionTreeClassifier(), 
              step=1, 
              cv=StratifiedKFold(10),
              scoring='accuracy')
rfecv.fit(X, y)
RFECV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
      estimator=DecisionTreeClassifier(), scoring='accuracy')
# Out:
# RFECV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#       estimator=DecisionTreeClassifier(), scoring='accuracy')

# %%
print("Optimum number of features: %d" % rfecv.n_features_)
# Out:
# Optimum number of features: 22

# %%
plt.figure( figsize=(16, 6))
plt.title('Total features selected versus accuracy')
plt.xlabel('Total features selected')
plt.ylabel('Model accuracy')
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Identifying the features RFE selected

rows = []

# Iterate over each feature
for i in range(X.shape[1]):
    row = {'feature': X.columns[i], 'support': rfecv.support_[i], 'ranking': rfecv.ranking_[i]}
    rows.append(row)

# Create the DataFrame from the list of rows
df_features = pd.DataFrame(rows)

# Sort by ranking and display the top 10 features
top_features = df_features.sort_values(by='ranking').head(10)
print(top_features)
# Out:
#                    feature  support  ranking
# 0                       ID     True        1
# 19        Check-in Service     True        1
# 18        Baggage Handling     True        1
# 17        Leg Room Service     True        1
# 16         Onboard Service     True        1
# 15  Inflight Entertainment     True        1
# 14            Seat Comfort     True        1
# 13         Online Boarding     True        1
# 12          Food and Drink     True        1
# 11           Gate Location     True        1

# %%
selected_features = rfecv.get_support(1)
X = df[df.columns[selected_features]]
X
# Out:
#               ID  Gender  Age  Customer Type  Type of Travel  Class  \
# 0            1.0       1   13              0               1      2
# 1            2.0       1   25              1               0      0
# 2            3.0       0   26              0               0      0
# 3            4.0       0   25              0               0      0
# 4            5.0       1   61              0               0      0
# ...          ...     ...  ...            ...             ...    ...
# 129875  129876.0       1   34              1               0      0
# 129876  129877.0       1   23              0               0      0
# 129877  129878.0       0   17              0               1      1
# 129878  129879.0       1   14              0               0      0
# 129879       0.0       0   42              0               1      1
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   460               25           18.0
# 1                   235                1            6.0
# 2                  1142                0            0.0
# 3                   562               11            9.0
# 4                   214                0            0.0
# ...                 ...              ...            ...
# 129875              526                0            0.0
# 129876              646                0            0.0
# 129877              828                0            0.0
# 129878             1127                0            0.0
# 129879              264                0            0.0
#
#         Departure Arrival Time Convenience  ...  Food and Drink  \
# 0                                        4  ...               5
# 1                                        2  ...               1
# 2                                        2  ...               5
# 3                                        5  ...               2
# 4                                        3  ...               4
# ...                                    ...  ...             ...
# 129875                                   3  ...               4
# 129876                                   4  ...               4
# 129877                                   5  ...               2
# 129878                                   3  ...               4
# 129879                                   5  ...               4
#
#         Online Boarding  Seat Comfort  Inflight Entertainment  \
# 0                     3             5                       5
# 1                     3             1                       1
# 2                     5             5                       5
# 3                     2             2                       2
# 4                     5             5                       3
# ...                 ...           ...                     ...
# 129875                3             4                       4
# 129876                4             4                       4
# 129877                1             2                       2
# 129878                4             4                       4
# 129879                2             2                       1
#
#         Onboard Service  Leg Room Service  Baggage Handling  Check-in Service  \
# 0                     4                 3                 4                 4
# 1                     1                 5                 3                 1
# 2                     4                 3                 4                 4
# 3                     2                 5                 3                 1
# 4                     3                 4                 4                 3
# ...                 ...               ...               ...               ...
# 129875                3                 2                 4                 4
# 129876                4                 5                 5                 5
# 129877                4                 3                 4                 5
# 129878                3                 2                 5                 4
# 129879                1                 2                 1                 1
#
#         In-flight Service  Cleanliness
# 0                       5            5
# 1                       4            1
# 2                       4            5
# 3                       4            2
# 4                       3            3
# ...                   ...          ...
# 129875                  5            4
# 129876                  5            4
# 129877                  4            2
# 129878                  5            4
# 129879                  1            1
#
# [105722 rows x 22 columns]

# %% [markdown]
# # Model Prediction

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1,train_size=0.80)

# %%
from pathlib import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Determine the shape of our training and testing sets.
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (84577, 22)
# (21145, 22)
# (84577,)
# (21145,)

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Creating the decision tree classifier instance.
model = tree.DecisionTreeClassifier()
# Fitting the model.
model = model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data.
predictions = model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0        11194          964
# Actual 1          891         8096
# Accuracy Score : 0.9122724048238354
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     12158
#            1       0.89      0.90      0.90      8987
#
#     accuracy                           0.91     21145
#    macro avg       0.91      0.91      0.91     21145
# weighted avg       0.91      0.91      0.91     21145

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.03147683, 0.00309345, 0.03097547, 0.047332  , 0.15215532,
#        0.02887022, 0.03858831, 0.0088912 , 0.01025166, 0.00769981,
#        0.06753825, 0.00767975, 0.00562405, 0.36520399, 0.02155497,
#        0.0624081 , 0.0110584 , 0.01776324, 0.01658584, 0.0324011 ,
#        0.01970384, 0.01314421])

# %%
# Sort the features by their importance.
feature_df = pd.DataFrame({'feature': X_train.columns, 'importance': importances})
feature_df = feature_df.sort_values('importance')
print(feature_df)

ax = feature_df.plot(kind='barh', x='feature', legend=False)
ax.set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
#                                feature  importance
# 1                               Gender    0.003093
# 12                      Food and Drink    0.005624
# 11                       Gate Location    0.007680
# 9   Departure Arrival Time Convenience    0.007700
# 7                      Departure Delay    0.008891
# 8                        Arrival Delay    0.010252
# 16                     Onboard Service    0.011058
# 21                         Cleanliness    0.013144
# 18                    Baggage Handling    0.016586
# 17                    Leg Room Service    0.017763
# 20                   In-flight Service    0.019704
# 14                        Seat Comfort    0.021555
# 5                                Class    0.028870
# 2                                  Age    0.030975
# 0                                   ID    0.031477
# 19                    Check-in Service    0.032401
# 6                      Flight Distance    0.038588
# 3                        Customer Type    0.047332
# 15              Inflight Entertainment    0.062408
# 10              Ease of Online Booking    0.067538
# 4                       Type of Travel    0.152155
# 13                     Online Boarding    0.365204
